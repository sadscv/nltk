# %%
import nltk

def performance(cfd, wordlist):
    lt = dict((word, cfd[word].max()) for word in wordlist)
    baseline_tagger = nltk.UnigramTagger(model=lt, 
                                         backoff=nltk.DefaultTagger('NN'))
    return baseline_tagger.evaluate(brown.tagged_sents(categories='news'))

def display():
    import pylab
    word_freqs = nltk.FreqDist(brown.words(categories='news')).most_common()
    words_by_freq = [w for (w, _) in word_freqs]
    cfd = nltk.ConditionalFreqDist(brown.tagged_words(categories='news'))
    sizes = 2 ** pylab.arrange(15)
    perfs = [perfomance(cfd, words_by_freq[:size]) for size in sizes]
    pylab.plot(sizes, perfs, '-bo')
    pylab.title('Lookup Tagger performance')
    pylab.xlabel('Model Size')
    pylab.ylabel('performance')
    pylab.show()

# %%
from nltk.corpus import brown

brown_news_tagged = brown.tagged_words(categories='news', tagset='universal')
data = nltk.ConditionalFreqDist((word.lower(), tag)
                                 for (word, tag) in brown_news_tagged)
for word in sorted(data.conditions()):
    print(data[word].most_common())
# for word in sorted(data.conditions()):
#     if len(data[word]) > 3:
#         tags = [tag for (tag, _) in data[word].most_common()]
#         print(word, ' '.join(tags))
# Out:
# [('.', 38)]
# [('NOUN', 5)]
# [('NOUN', 2)]
# [('NOUN', 1)]
# [('NOUN', 3)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 2)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 3)]
# [('NOUN', 5)]
# [('NOUN', 1)]
# [('NOUN', 7)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 2)]
# [('NOUN', 2)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 2)]
# [('NOUN', 1)]
# [('NOUN', 3)]
# [('NOUN', 2)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 2)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 2)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 4)]
# [('NOUN', 2)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 3)]
# [('NOUN', 3)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 1)]
# [('NOUN', 3)]
# ...

# %%
import nltk

def findtags(tag_prefixs, tagged_text):
    cfd = nltk.ConditionalFreqDist((tag, word) 
                                   for (word, tag) in tagged_text 
                                   if tag.startswith(tag_prefixs))
    return dict((tag, cfd[tag].most_common(5)) 
                 for tag in cfd.conditions())

tagdict = findtags('NN', 
                   nltk.corpus.brown.tagged_words(categories='news'))
for tag in sorted(tagdict):
    print(tag, tagdict[tag])
# Out:
# NN [('year', 137), ('time', 97), ('state', 88), ('week', 85), ('home', 72)]
# NN$ [("year's", 13), ("world's", 8), ("state's", 7), ("company's", 6), ("city's", 6)]
# NN$-HL [("Navy's", 1), ("Golf's", 1)]
# NN$-TL [("President's", 11), ("Gallery's", 3), ("Army's", 3), ("University's", 3), ("Administration's", 3)]
# NN-HL [('war', 2), ('problem', 2), ('business', 2), ('party', 2), ('Salary', 2)]
# NN-NC [('aya', 1), ('eva', 1), ('ova', 1)]
# NN-TL [('President', 88), ('House', 68), ('State', 59), ('University', 42), ('City', 41)]
# NN-TL-HL [('Fort', 2), ('Dr.', 1), ('Oak', 1), ('Mayor', 1), ('Basin', 1)]
# NNS [('years', 101), ('members', 69), ('people', 52), ('sales', 51), ('men', 46)]
# NNS$ [("children's", 7), ("women's", 5), ("janitors'", 3), ("men's", 3), ("builders'", 2)]
# NNS$-HL [("Idols'", 1), ("Dealers'", 1)]
# NNS$-TL [("Women's", 4), ("States'", 3), ("Giants'", 2), ("Princes'", 1), ("Pirates'", 1)]
# ...

# %%
brown_lrnd_tagged = nltk.corpus.brown.tagged_words(categories='learned',
                                                  tagset='universal')
tags = [b[1] for (a, b) 
        in nltk.bigrams(brown_lrnd_tagged) 
        if a[0] =='often']
fd = nltk.FreqDist(tags)
fd.tabulate()
# Out:
# VERB  ADV  ADP  ADJ    .  PRT
#   37    8    7    6    4    2

# %%
brown_learned_text = nltk.corpus.brown.words()
followed = nltk.FreqDist(b for (a, b) 
           in nltk.bigrams(brown_learned_text) 
           if a == 'want')
followed.most_common()
# Out:
# [('to', 162),
#  ('a', 14),
#  ('you', 13),
#  ('it', 12),
#  ('him', 11),
#  ('the', 11),
#  (',', 8),
#  ('me', 8),
#  ('no', 7),
#  ('her', 5),
#  ('.', 5),
#  ("''", 4),
#  ('and', 3),
#  ('is', 3),
#  ('from', 3),
#  ('this', 2),
#  ('of', 2),
#  ('--', 2),
#  ('us', 2),
#  ('my', 2),
#  ('adjustment', 1),
#  ('money', 1),
#  ('credited', 1),
#  ('none', 1),
#  ('pictures', 1),
#  ('Shirley', 1),
#  ('quaint', 1),
#  ('United', 1),
#  ('that', 1),
#  ('refunded', 1),
#  ('credit', 1),
#  ('anyone', 1),
#  ('additional', 1),
#  ('change', 1),
#  ('them', 1),
#  ("Barton's", 1),
#  ('town', 1),
#  ('Alfred', 1),
#  ('or', 1),
#  ('policy', 1),
#  ('comfort', 1),
#  ('one', 1),
#  ('comforts', 1),
#  ('discs', 1),
#  ('nothing', 1),
#  ('out', 1),
#  ('lots', 1),
#  ('not', 1),
#  ('in', 1),
#  ('sonny-boy', 1),
#  ('done', 1),
#  ('before', 1),
#  ('terry', 1),
#  ('around', 1),
#  ('!', 1),
#  ('occupations', 1),
#  ('with', 1),
#  ('respect', 1),
#  ('see', 1),
# ...

# %%
import nltk
from nltk import ConditionalFreqDist
from nltk.corpus import inaugural

inaugural.fileids()



cfd = ConditionalFreqDist((target, fileid[:4])
                          for fileid in inaugural.fileids()
                          for w in inaugural.words(fileid)
                          for target in ['america', 'citizen']
                          if w.lower().startswith(target) )

# cfd.plot(cumulative=True)
cfd.plot(conditions=['america'],)
# cfd.plot('target')

# %%
from nltk.book import *

fdist1 = FreqDist(text1)

names = nltk.corpus.

names.fileids()

male_names = names.words('male.txt')

female_names = names.words('female.txt')

same_names = (w for w in male_names if w in female_names)

cfd = ConditionalFreqDist((fileid, name[-1])
                          for fileid in names.fileids()
                          for name in names.words(fileid))

cfd.plot()

# %%
#名词
import nltk
from nltk.corpus import brown
brown_news_tagged = brown.tagged_words(categories='news', 
                                       tagset='universal')
# tag_fd = nltk.FreqDist(tag for (word, tag) in brown_news_tagged)
# tag_fd.most_common()
# tag_fd.plot(cumulative=True)
word_tag_pairs = nltk.bigrams(brown_news_tagged)
noun_preceders = [a[1] for (a, b) in word_tag_pairs if b[1] == 'NOUN']
fdist = nltk.FreqDist(noun_preceders)
[tag for (tag, _) in fdist.most_common()]
# Out:
# ['NOUN',
#  'DET',
#  'ADJ',
#  'ADP',
#  '.',
#  'VERB',
#  'CONJ',
#  'NUM',
#  'ADV',
#  'PRT',
#  'PRON',
#  'X']

# %%
wsj = nltk.corpus.treebank.tagged_words(tagset='universal')
word_tag_fd = nltk.FreqDist(wsj)
[(a, b) for (a, b) in word_tag_fd.most_common()]
# [wt[0] for (wt, _) in word_tag_fd.most_common() if wt[1] == 'VERB']
# Out:
# [((',', '.'), 4885),
#  (('the', 'DET'), 4038),
#  (('.', '.'), 3828),
#  (('of', 'ADP'), 2319),
#  (('to', 'PRT'), 2161),
#  (('a', 'DET'), 1874),
#  (('in', 'ADP'), 1554),
#  (('and', 'CONJ'), 1505),
#  (('*-1', 'X'), 1123),
#  (('0', 'X'), 1099),
#  (('*', 'X'), 965),
#  (('for', 'ADP'), 815),
#  (('*T*-1', 'X'), 806),
#  (("'s", 'PRT'), 761),
#  (('*U*', 'X'), 744),
#  (('$', '.'), 718),
#  (('The', 'DET'), 713),
#  (('``', '.'), 702),
#  (("''", '.'), 684),
#  (('is', 'VERB'), 671),
#  (('said', 'VERB'), 628),
#  (('that', 'ADP'), 513),
#  (('on', 'ADP'), 483),
#  (('it', 'PRON'), 476),
#  (('%', 'NOUN'), 445),
#  (('by', 'ADP'), 427),
#  (('at', 'ADP'), 402),
#  (('with', 'ADP'), 387),
#  (('from', 'ADP'), 386),
#  (('million', 'NUM'), 383),
#  (('Mr.', 'NOUN'), 375),
#  (('*-2', 'X'), 372),
#  (('was', 'VERB'), 367),
#  (('are', 'VERB'), 367),
#  (('be', 'VERB'), 356),
#  (('*T*-2', 'X'), 345),
#  (('has', 'VERB'), 339),
#  (('as', 'ADP'), 333),
#  (('its', 'PRON'), 332),
# ...

# %%
import nltk

wsj = nltk.corpus.treebank.tagged_words()
cfd1 = nltk.ConditionalFreqDist(wsj)
cfd2 = nltk.ConditionalFreqDist((tag, word) for (word, tag) in wsj)
vbn_list = list(cfd2['VBN'])
[w for w in vbn_list]
for i in range(10):
    print((vbn_list[i], 'VBN'))
#     print(wsj.index(('spun', 'VBN')))
    index = wsj.index((vbn_list[i],'VBN'))
    print(wsj[index - 4:index + 1])
# Out:
# ('spun', 'VBN')
# [('capital', 'NN'), ('--', ':'), ('might', 'MD'), ('be', 'VB'), ('spun', 'VBN')]
# ('sweetened', 'VBN')
# [('*U*', '-NONE-'), ('-RRB-', '-RRB-'), ('.', '.'), ('The', 'DT'), ('sweetened', 'VBN')]
# ('halted', 'VBN')
# [('expect', 'VBP'), ('it', 'PRP'), ('to', 'TO'), ('be', 'VB'), ('halted', 'VBN')]
# ('approved', 'VBN')
# [('0', '-NONE-'), ('President', 'NNP'), ('Bush', 'NNP'), ('has', 'VBZ'), ('approved', 'VBN')]
# ('stressed', 'VBN')
# [('It', 'PRP'), ('should', 'MD'), ('be', 'VB'), ('constantly', 'RB'), ('stressed', 'VBN')]
# ('banned', 'VBN')
# [('food', 'NN'), ('and', 'CC'), ('drinks', 'NNS'), ('are', 'VBP'), ('banned', 'VBN')]
# ('earned', 'VBN')
# [('floor', 'NN'), ('brokers', 'NNS'), ('long', 'RB'), ('have', 'VBP'), ('earned', 'VBN')]
# ('rectified', 'VBN')
# [('0', '-NONE-'), ('*T*-1', '-NONE-'), ('was', 'VBD'), ('rapidly', 'RB'), ('rectified', 'VBN')]
# ('ranged', 'VBN')
# ...

# %%
nltk.app.concordance()
